# %% [markdown]
# # Population Density by Municipality
#
# This notebook computes **population density** (inhabitants per km²) for each Spanish
# municipality and year using cleaned population data from the municipal census
# (*Padrón Municipal*) and official municipal boundaries from the National Geographic
# Institute (CNIG).
#
# Population density is generated as a **derived demographic attribute** at the
# municipality–year level and exported as a standalone dataset to ensure
# methodological clarity, traceability, and reproducibility.
#
# The resulting dataset will later be integrated with other demographic, services,
# agricultural, and land-use indicators.

# %% [markdown]
# ## Definition
#
# Population density measures the number of inhabitants per square kilometer in a
# given territorial unit.
#
# **Formula:**
#
# $$
# \text{Population Density} = \frac{\text{Total Population}}{\text{Area (km}^2\text{)}}
# $$
#
# This indicator is fundamental for understanding settlement patterns, territorial
# pressure, and rural depopulation dynamics.
#
# **Sources:**
# - Population data: INE – *Padrón Municipal de Habitantes*
# - Municipal boundaries: CNIG – *Centro de Descargas*
#   https://centrodedescargas.cnig.es/CentroDescargas/home
#
# **CRS methodology:**
# Area calculations are performed separately for each territory to minimise
# projection distortion:
# - Peninsula + Balearic Islands → ETRS89 / UTM zone 30N (**EPSG:25830**)
# - Canary Islands → REGCAN95 / UTM zone 28N (**EPSG:4083**)

# %%
"""
Notebook: 02_demography_population_density.ipynb
Purpose: Compute population density per municipality and year
Input:
  - data/demography/processed/01_padron_clean_1996_2024.csv
  - data/spatial/raw/recintos_municipales_inspire_peninbal_etrs89.shp
  - data/spatial/raw/recintos_municipales_inspire_canarias_regcan95.shp
Output: demography_population_density_1996_2024.csv
Author: Juan Zotes
Last updated: 2026-02-09
"""
# Out:
# '\nNotebook: 02_demography_population_density.ipynb\nPurpose: Compute population density per municipality and year\nInput:\n  - data/demography/processed/01_padron_clean_1996_2024.csv\n  - data/spatial/raw/recintos_municipales_inspire_peninbal_etrs89.shp\n  - data/spatial/raw/recintos_municipales_inspire_canarias_regcan95.shp\nOutput: demography_population_density_1996_2024.csv\nAuthor: Juan Zotes\nLast updated: 2026-02-09\n'

# %% [markdown]
# ## 1. Load required libraries and configure environment

# %%
from pathlib import Path
import warnings

import pandas as pd
import geopandas as gpd

warnings.filterwarnings('ignore')

# %%
# ── Project root and directory paths ──────────────────────────────────────────
PROJECT_ROOT = Path(r"/workspaces/rural-migration-land-use-spain")

# Input directories
DEMOGRAPHY_DIR = PROJECT_ROOT / "data" / "demography" / "processed"
SPATIAL_DIR    = PROJECT_ROOT / "data" / "spatial" / "raw"

# Output directory
DERIVED_DIR = PROJECT_ROOT / "data" / "demography" / "derived"
DERIVED_DIR.mkdir(parents=True, exist_ok=True)

# ── Input file paths ──────────────────────────────────────────────────────────
PADRON_FILE     = DEMOGRAPHY_DIR / "01_padron_clean_1996_2024.csv"
PENINSULA_SHP   = SPATIAL_DIR / "recintos_municipales_inspire_peninbal_etrs89.shp"
CANARIAS_SHP    = SPATIAL_DIR / "recintos_municipales_inspire_canarias_regcan95.shp"

# ── CRS for area computation (units in metres) ────────────────────────────────
CRS_PENINSULA = "EPSG:25830"   # ETRS89 / UTM zone 30N
CRS_CANARIAS  = "EPSG:4083"    # REGCAN95 / UTM zone 28N

# ── Verify that all input files exist ─────────────────────────────────────────
for label, path in [("Padrón", PADRON_FILE),
                     ("Peninsula SHP", PENINSULA_SHP),
                     ("Canarias SHP", CANARIAS_SHP)]:
    status = "✓" if path.exists() else "✗ NOT FOUND"
    print(f"{status}  {label}: {path}")
# Out:
# ✓  Padrón: /workspaces/rural-migration-land-use-spain/data/demography/processed/01_padron_clean_1996_2024.csv
# ✓  Peninsula SHP: /workspaces/rural-migration-land-use-spain/data/spatial/raw/recintos_municipales_inspire_peninbal_etrs89.shp
# ✓  Canarias SHP: /workspaces/rural-migration-land-use-spain/data/spatial/raw/recintos_municipales_inspire_canarias_regcan95.shp

# %% [markdown]
# ## 2. Load municipal boundaries (CNIG shapefiles)
#
# Two separate shapefiles are loaded, each in its own official projected CRS:
# - **Peninsula + Balearic Islands** — native CRS is ETRS89 geographic; reprojected to EPSG:25830
# - **Canary Islands** — native CRS is REGCAN95 geographic; reprojected to EPSG:4083
#
# Reprojecting each territory to its own UTM zone ensures that area calculations
# are in metres with minimal distortion.

# %%
# Load Peninsula + Balearic Islands
gdf_peninsula = gpd.read_file(PENINSULA_SHP)
print(f"Peninsula + Baleares: {len(gdf_peninsula)} features | CRS: {gdf_peninsula.crs}")

# Load Canary Islands
gdf_canarias = gpd.read_file(CANARIAS_SHP)
print(f"Canarias:             {len(gdf_canarias)} features | CRS: {gdf_canarias.crs}")
# Out:
# Peninsula + Baleares: 8132 features | CRS: EPSG:4258
# Canarias:             88 features | CRS: EPSG:4081

# %%
# Reproject each territory to its appropriate projected CRS
gdf_peninsula = gdf_peninsula.to_crs(CRS_PENINSULA)
gdf_canarias  = gdf_canarias.to_crs(CRS_CANARIAS)

print(f"Peninsula reprojected to {gdf_peninsula.crs}")
print(f"Canarias  reprojected to {gdf_canarias.crs}")
# Out:
# Peninsula reprojected to EPSG:25830
# Canarias  reprojected to EPSG:4083

# %% [markdown]
# ## 3. Extract municipality codes, compute areas, and filter anomalous entities
#
# The `NATCODE` field contains an 11-digit code whose **last 5 digits** correspond
# to the `Mun_Code` used in the demographic dataset.
#
# Example: NATCODE `34010404001` → Mun_Code `04001`
#
# **Anomalous territorial entities** (codes ≥ 53000 in the last 5 digits of
# NATCODE) are excluded. These are special administrative units that do not appear
# in the *Padrón Municipal* and are not relevant for demographic analysis.

# %%
def process_municipalities(gdf, territory_label):
    """
    Extract Mun_Code from NATCODE, compute area in km², and remove
    anomalous territorial entities (Mun_Code >= '53000').

    Parameters
    ----------
    gdf : GeoDataFrame
        Municipal boundaries with NATCODE field and projected geometry.
    territory_label : str
        Label for logging (e.g. 'Peninsula+Baleares').

    Returns
    -------
    DataFrame
        Mun_Code and Area_km2 for valid municipalities only.
    """
    gdf = gdf.copy()

    # Extract last 5 digits of NATCODE as Mun_Code (keep as string)
    gdf['Mun_Code'] = gdf['NATCODE'].astype(str).str[-5:]

    # Filter out anomalous territorial entities (>= '53000')
    # Using STRING comparison to preserve leading zeros
    anomalous_mask_full = gdf['Mun_Code'] >= '53000'
    n_anomalous = anomalous_mask_full.sum()

    if n_anomalous > 0:
        excluded = gdf.loc[anomalous_mask_full, ['Mun_Code', 'NAMEUNIT']]
        print(f"  ⚠ {territory_label}: excluding {n_anomalous} anomalous entities")
        print(f"    Codes: {excluded['Mun_Code'].tolist()}")

    gdf = gdf[~anomalous_mask_full].copy()

    # Compute area in km² (geometry units are metres after reprojection)
    gdf['Area_km2'] = gdf.geometry.area / 1_000_000

    print(f"  ✓ {territory_label}: {len(gdf)} valid municipalities")

    return gdf[['Mun_Code', 'Area_km2']]

# %%
# Process each territory separately (different CRS → different area calculations)
area_peninsula = process_municipalities(gdf_peninsula, "Peninsula+Baleares")
area_canarias  = process_municipalities(gdf_canarias,  "Canarias")

# Combine into a single area lookup table
area_lookup = pd.concat([area_peninsula, area_canarias], ignore_index=True)

print(f"\nTotal municipalities in area lookup: {len(area_lookup)}")
print(f"Unique Mun_Codes: {area_lookup['Mun_Code'].nunique()}")
# Out:
#   ⚠ Peninsula+Baleares: excluding 88 anomalous entities
#     Codes: ['53075', '53051', '53052', '53053', '53054', '53050', '53072', '53004', '53021', '53022', '53023', '53024', '53025', '53026', '53071', '53074', '53003', '53047', '53055', '53057', '53058', '53080', '53081', '53083', '53061', '53062', '53067', '53068', '53069', '53070', '53078', '53059', '53060', '53063', '53064', '53065', '53066', '53001', '53002', '53048', '53000', '54007', '54006', '53056', '54001', '54002', '54003', '54004', '54005', '53005', '53006', '53007', '53008', '53009', '53010', '53011', '53012', '53076', '53077', '53013', '53014', '53015', '53016', '53017', '53018', '53019', '53020', '53027', '53028', '53029', '53031', '53032', '53033', '53034', '53035', '53036', '53037', '53038', '53039', '53040', '53041', '53042', '53043', '53044', '53045', '53046', '53073', '53049']
#   ✓ Peninsula+Baleares: 8044 valid municipalities
#   ✓ Canarias: 88 valid municipalities
#
# ...

# %%
area_lookup.tail()
# Out:
#      Mun_Code   Area_km2
# 8127    38041  18.195296
# 8128    38042  24.546119
# 8129    38043  29.986308
# 8130    38044  24.214421
# 8131    38045  12.052575

# %%
# Check for duplicate Mun_Codes (should not exist after filtering)
duplicates = area_lookup[area_lookup.duplicated(subset=['Mun_Code'], keep=False)]

if len(duplicates) > 0:
    print(f"⚠ Warning: {len(duplicates)} duplicate Mun_Codes found:")
    print(duplicates)
else:
    print("✓ No duplicate municipality codes")
# Out:
# ✓ No duplicate municipality codes

# %% [markdown]
# ## 4. Load cleaned demographic data
#
# The cleaned historical municipal census dataset is loaded, filtered to the
# `Total` category (i.e. total population, not disaggregated by sex).

# %%
df = pd.read_csv(PADRON_FILE, dtype={"Mun_Code": str})

print(f"Loaded {len(df)} records")
print(f"Years: {df['Year'].min()} – {df['Year'].max()}")
print(f"Unique municipalities: {df['Mun_Code'].nunique()}")
# Out:
# Loaded 683088 records
# Years: 1996 – 2024
# Unique municipalities: 8132

# %%
# Keep only total population (exclude sex-disaggregated rows)
df_total = df[df['Cat'] == 'Total'].copy()

print(f"Records after filtering for 'Total': {len(df_total)}")
df_total.head()
# Out:
# Records after filtering for 'Total': 227696
#    Mun_Code               Mun    Cat  Year     Pop
# 2     01001  Alegría-Dulantzi  Total  1996  1234.0
# 5     01001  Alegría-Dulantzi  Total  1998  1259.0
# 8     01001  Alegría-Dulantzi  Total  1999  1329.0
# 11    01001  Alegría-Dulantzi  Total  2000  1401.0
# 14    01001  Alegría-Dulantzi  Total  2001  1486.0

# %% [markdown]
# ## 5. Merge population data with municipal areas

# %%
df_merged = df_total.merge(
    area_lookup,
    on='Mun_Code',
    how='left',
    validate='m:1'
)

print(f"Merged dataset: {len(df_merged)} records")
# Out:
# Merged dataset: 227696 records

# %%
# Check for municipalities without area data
missing_area = df_merged[df_merged['Area_km2'].isna()]

if len(missing_area) > 0:
    n_missing = missing_area['Mun_Code'].nunique()
    print(f"⚠ {n_missing} municipalities without area data:")
    print(missing_area[['Mun_Code', 'Mun']].drop_duplicates().to_string(index=False))
else:
    print("✓ All municipalities have area data")
# Out:
# ✓ All municipalities have area data

# %%
df_merged.tail()
# Out:
#        Mun_Code      Mun    Cat  Year      Pop   Area_km2
# 227691    52001  Melilla  Total  2020  87076.0  13.610572
# 227692    52001  Melilla  Total  2021  86261.0  13.610572
# 227693    52001  Melilla  Total  2022  85170.0  13.610572
# 227694    52001  Melilla  Total  2023  85491.0  13.610572
# 227695    52001  Melilla  Total  2024  85811.0  13.610572

# %% [markdown]
# ## 6. Compute population density
#
# Population density is calculated as inhabitants per km², following the standard
# definition used by the INE and in scientific literature.
#
# - Municipalities with `NaN` population → `Pop_Density = NaN`
# - Municipalities with area ≤ 0 or `NaN` → `Pop_Density = NaN`

# %%
# Compute density; NaN propagates naturally from Pop or Area_km2
df_merged['Pop_Density'] = df_merged['Pop'] / df_merged['Area_km2']

# Safeguard: set density to NaN where area is zero or negative
df_merged.loc[df_merged['Area_km2'] <= 0, 'Pop_Density'] = float('nan')

print("Pop_Density statistics:")
print(df_merged['Pop_Density'].describe())
# Out:
# Pop_Density statistics:
# count    227207.000000
# mean        167.773933
# std         872.349092
# min           0.109292
# 25%           5.424845
# 50%          14.421424
# 75%          53.306640
# max       24902.934915
# Name: Pop_Density, dtype: float64

# %% [markdown]
# ## 7. Quality control

# %%
latest_year = df_merged['Year'].max()
df_latest = df_merged[df_merged['Year'] == latest_year]

print(f"=== Highest density ({latest_year}) ===")
print(df_latest.nlargest(10, 'Pop_Density')[
    ['Mun_Code', 'Mun', 'Pop', 'Area_km2', 'Pop_Density']
].to_string(index=False))

print(f"\n=== Lowest density ({latest_year}) ===")
print(df_latest.nsmallest(10, 'Pop_Density')[
    ['Mun_Code', 'Mun', 'Pop', 'Area_km2', 'Pop_Density']
].to_string(index=False))
# Out:
# === Highest density (2024) ===
# Mun_Code                         Mun       Pop   Area_km2  Pop_Density
#    46117                   Emperador     693.0   0.028792 24069.363872
#    46169                     Mislata   46153.0   2.032535 22707.114965
#    46054                  Benetússer   16322.0   0.778862 20956.207735
#    08101 Hospitalet de Llobregat, L'  279993.0  13.653843 20506.533632
#    08245    Santa Coloma de Gramenet  121203.0   7.121581 17019.114206
#    08019                   Barcelona 1702547.0 101.144327 16832.847148
#    08172               Premià de Mar   28951.0   1.988443 14559.635018
#    48078                 Portugalete   44766.0   3.132690 14289.954700
#    31901           Barañáin/Barañain   19606.0   1.391241 14092.458159
#    08904            Badia del Vallès   13118.0   0.935576 14021.312097
#
# === Lowest density (2024) ===
# Mun_Code                      Mun  Pop   Area_km2  Pop_Density
#    45080           Illán de Vacas  2.0   9.149795     0.218584
# ...

# %%
# Sanity checks
n_negative = (df_merged['Pop_Density'] < 0).sum()
n_infinite = (df_merged['Pop_Density'] == float('inf')).sum()
n_nan      = df_merged['Pop_Density'].isna().sum()

print(f"{'✓' if n_negative == 0 else '⚠'} Negative density values: {n_negative}")
print(f"{'✓' if n_infinite == 0 else '⚠'} Infinite density values: {n_infinite}")
print(f"ℹ NaN density values: {n_nan}")
# Out:
# ✓ Negative density values: 0
# ✓ Infinite density values: 0
# ℹ NaN density values: 489

# %% [markdown]
# ## 8. Prepare and export final dataset
#
# The output CSV contains one row per municipality-year with the following columns:
# - `Year` — census year
# - `Mun_Code` — 5-digit municipality code
# - `Mun` — municipality name
# - `Area_km2` — municipal area in km² (computed from CNIG boundaries)
# - `Pop_Density` — inhabitants per km² (NaN where population is missing)

# %%
# Select final columns
density_df = df_merged[
    ['Year', 'Mun_Code', 'Mun', 'Area_km2', 'Pop_Density']
].copy()

# Round for readability
density_df['Area_km2']    = density_df['Area_km2'].round(4)
density_df['Pop_Density'] = density_df['Pop_Density'].round(2)

print(f"Final dataset: {len(density_df)} records")
print(f"Municipalities: {density_df['Mun_Code'].nunique()}")
print(f"Years: {density_df['Year'].min()} – {density_df['Year'].max()}")
density_df.head(10)
# Out:
# Final dataset: 227696 records
# Municipalities: 8132
# Years: 1996 – 2024
#    Year Mun_Code               Mun  Area_km2  Pop_Density
# 0  1996    01001  Alegría-Dulantzi   19.9313        61.91
# 1  1998    01001  Alegría-Dulantzi   19.9313        63.17
# 2  1999    01001  Alegría-Dulantzi   19.9313        66.68
# 3  2000    01001  Alegría-Dulantzi   19.9313        70.29
# 4  2001    01001  Alegría-Dulantzi   19.9313        74.56
# 5  2002    01001  Alegría-Dulantzi   19.9313        80.18
# 6  2003    01001  Alegría-Dulantzi   19.9313        85.64
# 7  2004    01001  Alegría-Dulantzi   19.9313        96.28
# 8  2005    01001  Alegría-Dulantzi   19.9313       102.75
# 9  2006    01001  Alegría-Dulantzi   19.9313       109.83

# %%
# Export
output_file = DERIVED_DIR / "demography_population_density_1996_2024.csv"
density_df.to_csv(output_file, index=False)

print(f"✓ Exported to: {output_file}")
# Out:
# ✓ Exported to: /workspaces/rural-migration-land-use-spain/data/demography/derived/demography_population_density_1996_2024.csv
